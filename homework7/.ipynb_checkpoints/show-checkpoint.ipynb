# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('solution.txt', sep=' ', header=None)

# %%
true_df = df.iloc[:, :-1]

# %%
data = true_df.values
data
# Out:
# array([[0.  , 0.  , 0.  , ..., 0.  , 0.  , 0.  ],
#        [0.03, 0.03, 0.03, ..., 0.03, 0.03, 0.03],
#        [0.06, 0.06, 0.06, ..., 0.06, 0.06, 0.06],
#        ...,
#        [0.06, 0.06, 0.06, ..., 0.02, 0.02, 0.02],
#        [0.03, 0.03, 0.03, ..., 0.01, 0.01, 0.01],
#        [0.  , 0.  , 0.  , ..., 0.  , 0.  , 0.  ]])

# %%
gr = plt.imshow(data, cmap='rainbow')
plt.colorbar(gr)
