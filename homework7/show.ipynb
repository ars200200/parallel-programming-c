# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('solution.txt', sep=' ', header=None)

# %%
true_df = df.iloc[:, :-1]

# %%
data = true_df.values
data
# Out:
# array([[0.  , 0.  , 0.  , ..., 0.  , 0.  , 0.  ],
#        [0.03, 0.03, 0.03, ..., 0.03, 0.03, 0.03],
#        [0.06, 0.06, 0.06, ..., 0.06, 0.06, 0.06],
#        ...,
#        [0.06, 0.06, 0.06, ..., 0.02, 0.02, 0.02],
#        [0.03, 0.03, 0.03, ..., 0.01, 0.01, 0.01],
#        [0.  , 0.  , 0.  , ..., 0.  , 0.  , 0.  ]])

# %%
gr = plt.imshow(data, cmap='rainbow', extent=(0,1,0,1))
plt.colorbar(gr)

# %%
def f(lst):
    lst[-1] = 1
    
f(lst)
lst
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       4 def f(lst):
#       5     lst[-1] = 1
# ----> 7 f(lst)
#       8 lst
#
# Cell In[15], line 5, in f(lst)
#       4 def f(lst):
# ----> 5     lst[-1] = 1
#
# TypeError: 'tuple' object does not support item assignment
