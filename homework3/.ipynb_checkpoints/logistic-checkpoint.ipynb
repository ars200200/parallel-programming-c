# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("output.txt",delimiter=',',dtype=float)
plt.figure(figsize = (64,64))
r = np.arange(0, 4, 4/100)
for i in range(100):
    
    plt.plot([r[i]] * 100, data[i], )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       3 r = np.arange(0, 4, 4/2048)
#       4 for i in range(2048):
# ----> 6     plt.plot([r[i]] * 2048, data[i], )
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/matplotlib/pyplot.py:2812, in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/matplotlib/axes/_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
# ...

# %%
np.max(data)
# Out:
# 49
